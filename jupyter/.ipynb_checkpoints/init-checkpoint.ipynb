# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import utils.Config as cfg
import utils.AlphaVantageUtils as av
import utils.PostgresUtils as pg

# %%
df_prices = pg.get_prices(av._TIC_MICROSOFT, av._INT_DAILY, None, None, None)

df_prices.drop(columns=['id'], inplace=True)

df_prices.index = df_prices['datetime']

# %%
df_prices.head()
# Out:
#            ticker interval   datetime    open     high     low   close  \
# datetime
# 2020-01-22   MSFT        D 2020-01-22  167.40  167.490  165.68  165.70
# 2020-01-21   MSFT        D 2020-01-21  166.68  168.190  166.43  166.50
# 2020-01-17   MSFT        D 2020-01-17  167.42  167.467  165.43  167.10
# 2020-01-16   MSFT        D 2020-01-16  164.35  166.240  164.03  166.17
# 2020-01-15   MSFT        D 2020-01-15  162.62  163.940  162.57  163.18
#
#                 volume
# datetime
# 2020-01-22  24062100.0
# 2020-01-21  29223500.0
# 2020-01-17  34371700.0
# 2020-01-16  23865400.0
# 2020-01-15  21417900.0

# %%
# Using plotly.express
import plotly.express as px


fig = px.line(df_prices, x=pg._COL_DATETIME, y=pg._COL_CLOSE)
fig.show()
# Out:
# <div>
#
#
#             <div id="a8f79c04-6eef-4a56-a57e-a9b852abf9a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a8f79c04-6eef-4a56-a57e-a9b852abf9a2")) {
#                     Plotly.newPlot(
#                         'a8f79c04-6eef-4a56-a57e-a9b852abf9a2',
# ...

# %%
# !python -m pip install ga-capstone-hakngrow==0.0.18
